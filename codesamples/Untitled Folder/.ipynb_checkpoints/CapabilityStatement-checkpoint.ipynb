# %%
import os
import json
import requests

FHIR_BASE = "http://localhost:8080/fhir/"

headers = {"Content-Type": "application/fhir+json;charset=utf-8"}

# %%
r = requests.get(url = FHIR_BASE + "Patient?_total=accurate", headers = headers)

# %%
print(r.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "09a8a6eb-2617-4dbb-b0d6-ed8a60992d53",
#   "meta": {
#     "lastUpdated": "2022-09-14T01:02:19.032+00:00"
#   },
#   "type": "searchset",
#   "total": 1510,
#   "link": [ {
#     "relation": "self",
#     "url": "http://localhost:8080/fhir/Patient?_total=accurate"
#   }, {
#     "relation": "next",
#     "url": "http://localhost:8080/fhir?_getpages=09a8a6eb-2617-4dbb-b0d6-ed8a60992d53&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "http://localhost:8080/fhir/Patient/1",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-08-14T15:25:34.634+00:00",
#         "source": "#WCCwANi8BxaCGFPB"
#       },
#       "text": {
#         "status": "generated",
# ...
